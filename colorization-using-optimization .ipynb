# %% [markdown]
# <a href="https://colab.research.google.com/github/NamSee04/JupyterNotebook/blob/main/colorization-using-optimization%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Clone the repository

# %%
# !git clone https://github.com/soumik12345/colorization-using-optimization
# %cd colorization-using-optimization
# Out:
# Cloning into 'colorization-using-optimization'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 189 (delta 62), reused 152 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (189/189), 9.23 MiB | 13.61 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# /content/colorization-using-optimization

# %% [markdown]
# ## Baseline Colorizer

# %%
from colorization import Colorizer

# %%
colorizer = Colorizer(
    gray_image_file='./data/original/example.png',
    visual_clues_file='./data/visual-clues/example.png'
)

# %%
colorizer.plot_inputs()

# %%
# %%time
result = colorizer.colorize()
# Out:
# 100%|██████████| 265/265 [00:14<00:00, 18.52it/s]
# CPU times: user 17.7 s, sys: 498 ms, total: 18.2 s
# Wall time: 18.3 s

# %%
colorizer.plot_results(result)

# %% [markdown]
# ## Iterative Colorizer

# %%
from colorization import IterativeColorizer

# %%
colorizer = IterativeColorizer(
    original_image='./data/original/example.png',
    visual_clues='./data/visual-clues/example.png'
)

# %%
colorizer.plot_inputs()

# %%
# %%time
colorizer.colorize(epochs=600, log_interval=100)
# Out:
# Finding neighbouring pixels...
# 100%|██████████| 320/320 [00:05<00:00, 54.78it/s]
# Optimizing iteratively...
# 100%|██████████| 600/600 [00:03<00:00, 182.47it/s]
# CPU times: user 10.4 s, sys: 319 ms, total: 10.7 s
# Wall time: 10.9 s

# %%
colorizer.plot_results(log_interval=100)
